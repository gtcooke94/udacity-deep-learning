# %% [markdown]
# # 2.1.9 Perceptrons as Logical Operators

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
def x2(x1, w1, w2, b):
    return (-w1 * x1 - b) / w2
x1s = np.linspace(-10, 10, 50)

# %% [markdown]
# ### AND

# %%
# TODO: Set weight1, weight2, and bias
weight1 = .8
weight2 = .8
bias = -0.9

x2s = x2(x1s, weight1, weight2, bias)


# DON'T CHANGE ANYTHING BELOW
# Inputs and outputs
test_inputs = [(0, 0), (0, 1), (1, 0), (1, 1)]
correct_outputs = [False, False, False, True]
outputs = []

# Generate and check output
for test_input, correct_output in zip(test_inputs, correct_outputs):
    linear_combination = weight1 * test_input[0] + weight2 * test_input[1] + bias
    output = int(linear_combination >= 0)
    is_correct_string = 'Yes' if output == correct_output else 'No'
    outputs.append([test_input[0], test_input[1], linear_combination, output, is_correct_string])

# Print output
num_wrong = len([output[4] for output in outputs if output[4] == 'No'])
output_frame = pd.DataFrame(outputs, columns=['Input 1', '  Input 2', '  Linear Combination', '  Activation Output', '  Is Correct'])
if not num_wrong:
    print('Nice!  You got it all correct.\n')
else:
    print('You got {} wrong.  Keep trying!\n'.format(num_wrong))
print(output_frame.to_string(index=False))

plt.plot(x1s, x2s)
plt.ylim([0, 2])
plt.xlim([0, 2])
plt.scatter([1], [1], color='b')
plt.scatter([0], [0], color='r')
plt.scatter([0], [1], color='r')
plt.scatter([1], [0], color='r')
# Out:
# Nice!  You got it all correct.
#
#  Input 1    Input 2    Linear Combination    Activation Output   Is Correct
#        0          0                  -0.9                    0          Yes
#        0          1                  -0.1                    0          Yes
#        1          0                  -0.1                    0          Yes
#        1          1                   0.7                    1          Yes

# %% [markdown]
# ## OR

# %% [markdown]
# We can move this line around by adjusting weights and biases
# $$
# x_{int} = \frac{-b}{w_1}\\
# y_{int} = \frac{-b}{w_2}\\
# \text{slope} = \frac{-w_1}{w_2}\\
# $$

# %% [markdown]
# By shifting biases

# %%
# TODO: Set weight1, weight2, and bias
weight1 = .8
weight2 = .8
bias = -0.2

x2s = x2(x1s, weight1, weight2, bias)


# DON'T CHANGE ANYTHING BELOW
# Inputs and outputs
test_inputs = [(0, 0), (0, 1), (1, 0), (1, 1)]
correct_outputs = [False, True, True, True]
outputs = []

# Generate and check output
for test_input, correct_output in zip(test_inputs, correct_outputs):
    linear_combination = weight1 * test_input[0] + weight2 * test_input[1] + bias
    output = int(linear_combination >= 0)
    is_correct_string = 'Yes' if output == correct_output else 'No'
    outputs.append([test_input[0], test_input[1], linear_combination, output, is_correct_string])

# Print output
num_wrong = len([output[4] for output in outputs if output[4] == 'No'])
output_frame = pd.DataFrame(outputs, columns=['Input 1', '  Input 2', '  Linear Combination', '  Activation Output', '  Is Correct'])
if not num_wrong:
    print('Nice!  You got it all correct.\n')
else:
    print('You got {} wrong.  Keep trying!\n'.format(num_wrong))
print(output_frame.to_string(index=False))

plt.plot(x1s, x2s)
plt.ylim([0, 2])
plt.xlim([0, 2])
plt.scatter([1], [1], color='b')
plt.scatter([0], [0], color='r')
plt.scatter([0], [1], color='b')
plt.scatter([1], [0], color='b')
# Out:
# Nice!  You got it all correct.
#
#  Input 1    Input 2    Linear Combination    Activation Output   Is Correct
#        0          0                  -0.2                    0          Yes
#        0          1                   0.6                    1          Yes
#        1          0                   0.6                    1          Yes
#        1          1                   1.4                    1          Yes

# %% [markdown]
# By Increasing Weights - this brings your intercepts closer to 0:
# $$
# x_{int} = \frac{-b}{w_1}\\
# y_{int} = \frac{-b}{w_2}\\
# \text{slope} = \frac{-w_1}{-w_2}\\
# $$

# %%
# TODO: Set weight1, weight2, and bias
weight1 = 1.1
weight2 = 1.1
bias = -0.9

x2s = x2(x1s, weight1, weight2, bias)


# DON'T CHANGE ANYTHING BELOW
# Inputs and outputs
test_inputs = [(0, 0), (0, 1), (1, 0), (1, 1)]
correct_outputs = [False, True, True, True]
outputs = []

# Generate and check output
for test_input, correct_output in zip(test_inputs, correct_outputs):
    linear_combination = weight1 * test_input[0] + weight2 * test_input[1] + bias
    output = int(linear_combination >= 0)
    is_correct_string = 'Yes' if output == correct_output else 'No'
    outputs.append([test_input[0], test_input[1], linear_combination, output, is_correct_string])

# Print output
num_wrong = len([output[4] for output in outputs if output[4] == 'No'])
output_frame = pd.DataFrame(outputs, columns=['Input 1', '  Input 2', '  Linear Combination', '  Activation Output', '  Is Correct'])
if not num_wrong:
    print('Nice!  You got it all correct.\n')
else:
    print('You got {} wrong.  Keep trying!\n'.format(num_wrong))
print(output_frame.to_string(index=False))

plt.plot(x1s, x2s)
plt.ylim([0, 2])
plt.xlim([0, 2])
plt.scatter([1], [1], color='b')
plt.scatter([0], [0], color='r')
plt.scatter([0], [1], color='b')
plt.scatter([1], [0], color='b')
# Out:
# Nice!  You got it all correct.
#
#  Input 1    Input 2    Linear Combination    Activation Output   Is Correct
#        0          0                  -0.9                    0          Yes
#        0          1                   0.2                    1          Yes
#        1          0                   0.2                    1          Yes
#        1          1                   1.3                    1          Yes

# %% [markdown]
# ## NOT

# %% [markdown]
# We want a NOT on the second perceptron input, so we need a horizontal line that will give "upside down" labels

# %%
import pandas as pd

# TODO: Set weight1, weight2, and bias
weight1 = 0
weight2 = -1
bias = 0.0


# DON'T CHANGE ANYTHING BELOW
# Inputs and outputs
test_inputs = [(0, 0), (0, 1), (1, 0), (1, 1)]
correct_outputs = [True, False, True, False]
outputs = []

# Generate and check output
for test_input, correct_output in zip(test_inputs, correct_outputs):
    linear_combination = weight1 * test_input[0] + weight2 * test_input[1] + bias
    output = int(linear_combination >= 0)
    is_correct_string = 'Yes' if output == correct_output else 'No'
    outputs.append([test_input[0], test_input[1], linear_combination, output, is_correct_string])

# Print output
num_wrong = len([output[4] for output in outputs if output[4] == 'No'])
output_frame = pd.DataFrame(outputs, columns=['Input 1', '  Input 2', '  Linear Combination', '  Activation Output', '  Is Correct'])
if not num_wrong:
    print('Nice!  You got it all correct.\n')
else:
    print('You got {} wrong.  Keep trying!\n'.format(num_wrong))
print(output_frame.to_string(index=False))

x2s = x2(x1s, weight1, weight2, bias)
plt.plot(x1s, x2s)
plt.ylim([-1, 2])
plt.xlim([-1, 2])
plt.scatter([1], [1], color='r')
plt.scatter([0], [0], color='b')
plt.scatter([0], [1], color='r')
plt.scatter([1], [0], color='b')
# Out:
# Nice!  You got it all correct.
#
#  Input 1    Input 2    Linear Combination    Activation Output   Is Correct
#        0          0                   0.0                    1          Yes
#        0          1                  -1.0                    0          Yes
#        1          0                   0.0                    1          Yes
#        1          1                  -1.0                    0          Yes

# %% [markdown]
# ### XOR

# %% [markdown]
# To get an XOR gate, we want the below results. We cannot make this boundary with a line, and thus cannot create this relationship with a single perceptron. We need a mutlilayer network of perceptrons:
# ![](images/xor_perceptron.png "")
#
# We can get nonlinear relationships by combining linear perceptrons.

# %%
plt.scatter([1], [1], color='r')
plt.scatter([0], [0], color='r')
plt.scatter([0], [1], color='b')
plt.scatter([1], [0], color='b')

# %% [markdown]
# ## Experimenting with Weights and Biases

# %% [markdown]
# We can see from the graph below that, for example, a bias of -0.7 gets us OR, and a bias of -0.9 gets us AND.

# %%
import matplotlib.pyplot as plt
import numpy as np
def x2(x1, w1, w2, b):
    return (-w1 * x1 - b) / w2
weight1 = .8
weight2 = .8
x1s = np.linspace(-10, 10, 50)
x2s = x2(x1s, weight1, weight2, bias)
x3s = x2(x1s, weight1, weight2, -1.1)
x4s = x2(x1s, weight1, weight2, .1)
x5s = x2(x1s, weight1, weight2, 0)
x6s = x2(x1s, weight1, weight2, -0.3)

plt.plot(x1s, x2s, color='b')
plt.plot(x1s, x3s, color='r')
plt.plot(x1s, x4s, color='g')
plt.plot(x1s, x5s, color='y')
plt.plot(x1s, x6s, color='k')
plt.ylim([-2, 4])
plt.xlim([-2, 4])
plt.scatter([1], [1])
plt.scatter([0], [0])
plt.scatter([0], [1])
plt.scatter([1], [0])
plt.axhline(0)
plt.axvline(0)
plt.title("Experimenting wit Bias Changes")
plt.legend([bias, -1.1, .1, 0, -0.3])
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
const_bias = 0.1
weight_combos = [(.5, .5), (1, .5), (.5, 1), (1, 1), (-.5, -.5), (-.5, -1), (-.5, 1), (1, -.5)]
def x2(x1, w1, w2, b):
    return (-w1 * x1 - b) / w2
x1s = np.linspace(-10, 10, 50)
x2s_vary_weight = [x2(x1s, w1, w2, const_bias) for w1, w2 in weight_combos]    
    
for x2s in x2s_vary_weight:
    plt.plot(x1s, x2s)
plt.ylim([-4, 4])
plt.xlim([-4, 4])
plt.scatter([1], [1])
plt.scatter([0], [0])
plt.scatter([0], [1])
plt.scatter([1], [0])
plt.axhline(0, linestyle="--")
plt.axvline(0, linestyle="--")
plt.title("Experimenting with Weight Changes")
plt.legend(weight_combos)
plt.show()
